# %%
# Dependencies
import os 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import time
from scipy.stats import linregress

# Import API key
from api_keys import g_key

# Import Dependencies for Heatmap of Overdose Deaths
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

#Reading in Files
cdc_df = pd.read_csv("Resource/VSRR_Provisional_Drug_Overdose_Death_Counts_2015_2021.csv", thousands=',')
care_df = pd.read_csv("Resource/Medicare_Opioid_Prescribing_Data_2013_2019.csv", low_memory = False)
caid_df = pd.read_csv("Resource/Medicaid_Opioid_Prescribing_data_2013_2019.csv", low_memory = False)

# %%
# Filtering Medcaid dropping year 2013 & 2014 and filtering for all plan types
caid_year = caid_df.loc[(caid_df["Year"] != 2013) & (caid_df["Year"] != 2014)]
caid_clean = caid_year.loc[caid_year["Plan_Type"]=="All"]
# Reset the index values for the dataframe
caid_clean = caid_clean.reset_index(drop=True)
caid_clean
# Out:
#      Year   Geo_Lvl  Geo_Cd       Geo_Desc Plan_Type  Tot_Opioid_Clms  \
# 0    2019  National     NaN       National       All       21978286.0
# 1    2019     State     1.0        Alabama       All         224310.0
# 2    2019     State     2.0         Alaska       All          65394.0
# 3    2019     State     4.0        Arizona       All         595206.0
# 4    2019     State     5.0       Arkansas       All         216081.0
# ..    ...       ...     ...            ...       ...              ...
# 255  2015     State    51.0       Virginia       All         583116.0
# 256  2015     State    53.0     Washington       All        1136474.0
# 257  2015     State    54.0  West Virginia       All         520370.0
# 258  2015     State    55.0      Wisconsin       All         962286.0
# 259  2015     State    56.0        Wyoming       All          39088.0
#
#         Tot_Clms  Opioid_Prscrbng_Rate  Opioid_Prscrbng_Rate_5Y_Chg  \
# 0    677248025.0                  3.25                        -3.22
# 1      7230251.0                  3.10                        -3.23
# 2      1434139.0                  4.56                        -3.33
# 3     14923326.0                  3.99                        -5.14
# 4      4999626.0                  4.32                        -3.12
# ..           ...                   ...                          ...
# 255   10186332.0                  5.72                          NaN
# 256   14016747.0                  8.11                          NaN
# 257    9293729.0                  5.60                          NaN
# 258   11306189.0                  8.51                          NaN
# 259     534212.0                  7.32                          NaN
#
#      Opioid_Prscrbng_Rate_1Y_Chg  LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0                          -0.44           3108845.0                    14.15
# 1                          -1.08             10308.0                     4.60
# 2                          -1.20              8268.0                    12.64
# 3                          -0.75             44311.0                     7.44
# 4                          -0.88              8129.0                     3.76
# ..                           ...                 ...                      ...
# 255                        -0.62             42311.0                     7.26
# 256                        -0.89            106143.0                     9.34
# 257                        -1.30             25575.0                     4.91
# 258                        -0.35            146248.0                    15.20
# 259                        -0.48              3792.0                     9.70
#
#      LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                              6.67                            4.62
# 1                              0.16                            0.48
# 2                              0.88                           -0.71
# 3                             -2.79                           -0.52
# 4                             -0.34                           -1.05
# ..                              ...                             ...
# 255                             NaN                           -0.26
# 256                             NaN                            0.18
# 257                             NaN                            0.66
# 258                             NaN                            1.04
# 259                             NaN                           -0.49
#
# [260 rows x 14 columns]

# %%
# Changing column name to state for merging later
caid_clean = caid_clean.rename(columns={"Geo_Desc":"State"})

caid_clean
# Out:
#      Year   Geo_Lvl  Geo_Cd          State Plan_Type  Tot_Opioid_Clms  \
# 0    2019  National     NaN       National       All       21978286.0
# 1    2019     State     1.0        Alabama       All         224310.0
# 2    2019     State     2.0         Alaska       All          65394.0
# 3    2019     State     4.0        Arizona       All         595206.0
# 4    2019     State     5.0       Arkansas       All         216081.0
# ..    ...       ...     ...            ...       ...              ...
# 255  2015     State    51.0       Virginia       All         583116.0
# 256  2015     State    53.0     Washington       All        1136474.0
# 257  2015     State    54.0  West Virginia       All         520370.0
# 258  2015     State    55.0      Wisconsin       All         962286.0
# 259  2015     State    56.0        Wyoming       All          39088.0
#
#         Tot_Clms  Opioid_Prscrbng_Rate  Opioid_Prscrbng_Rate_5Y_Chg  \
# 0    677248025.0                  3.25                        -3.22
# 1      7230251.0                  3.10                        -3.23
# 2      1434139.0                  4.56                        -3.33
# 3     14923326.0                  3.99                        -5.14
# 4      4999626.0                  4.32                        -3.12
# ..           ...                   ...                          ...
# 255   10186332.0                  5.72                          NaN
# 256   14016747.0                  8.11                          NaN
# 257    9293729.0                  5.60                          NaN
# 258   11306189.0                  8.51                          NaN
# 259     534212.0                  7.32                          NaN
#
#      Opioid_Prscrbng_Rate_1Y_Chg  LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0                          -0.44           3108845.0                    14.15
# 1                          -1.08             10308.0                     4.60
# 2                          -1.20              8268.0                    12.64
# 3                          -0.75             44311.0                     7.44
# 4                          -0.88              8129.0                     3.76
# ..                           ...                 ...                      ...
# 255                        -0.62             42311.0                     7.26
# 256                        -0.89            106143.0                     9.34
# 257                        -1.30             25575.0                     4.91
# 258                        -0.35            146248.0                    15.20
# 259                        -0.48              3792.0                     9.70
#
#      LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                              6.67                            4.62
# 1                              0.16                            0.48
# 2                              0.88                           -0.71
# 3                             -2.79                           -0.52
# 4                             -0.34                           -1.05
# ..                              ...                             ...
# 255                             NaN                           -0.26
# 256                             NaN                            0.18
# 257                             NaN                            0.66
# 258                             NaN                            1.04
# 259                             NaN                           -0.49
#
# [260 rows x 14 columns]

# %%
# Filtering Medicaid Data by Breakout Type and Perscription Geographic Levels for National or State levels
care_year = care_df.loc[(care_df["Year"] != 2013) & (care_df["Year"] != 2014)]
care_clean = care_year.loc[(care_year["Breakout_Type"]=="Totals") &  (care_year["Prscrbr_Geo_Lvl"]=="National") | (care_year["Prscrbr_Geo_Lvl"]=="State")  &  (care_year["Breakout"]=="Overall") & (care_df["Prscrbr_Geo_Desc"] != 'American Samoa')& (care_df["Prscrbr_Geo_Desc"] != 'Guam') & (care_df["Prscrbr_Geo_Desc"] != 'American Samoa') & (care_df["Prscrbr_Geo_Desc"] != 'Northern Mariana Islands') & (care_df["Prscrbr_Geo_Desc"] != 'Puerto Rico') & (care_df["Prscrbr_Geo_Desc"] != 'Virgin Islands')]

# Reset the index values for the dataframe
care_clean = care_clean.reset_index(drop=True)
care_clean
# Out:
#      Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd Prscrbr_Geo_Desc  RUCA_Cd  \
# 0    2019        National             NaN         National      NaN
# 1    2019           State             1.0          Alabama      NaN
# 2    2019           State             2.0           Alaska      NaN
# 3    2019           State             4.0          Arizona      NaN
# 4    2019           State             5.0         Arkansas      NaN
# ..    ...             ...             ...              ...      ...
# 255  2015           State            51.0         Virginia      NaN
# 256  2015           State            53.0       Washington      NaN
# 257  2015           State            54.0    West Virginia      NaN
# 258  2015           State            55.0        Wisconsin      NaN
# 259  2015           State            56.0          Wyoming      NaN
#
#     Breakout_Type Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  \
# 0          Totals  Overall     1239380.0             803549.0
# 1          Totals  Overall       15575.0               9739.0
# 2          Totals  Overall        2847.0               1935.0
# 3          Totals  Overall       25876.0              16578.0
# 4          Totals  Overall        9700.0               7258.0
# ..            ...      ...           ...                  ...
# 255        Totals  Overall       25319.0              19755.0
# 256        Totals  Overall       25351.0              19532.0
# 257        Totals  Overall        7064.0               5174.0
# 258        Totals  Overall       20540.0              16177.0
# 259        Totals  Overall        1760.0               1363.0
#
#      Tot_Opioid_Clms      Tot_Clms  Opioid_Prscrbng_Rate  \
# 0         66138200.0  1.501140e+09                  4.41
# 1          1814583.0  2.800821e+07                  6.48
# 2            80311.0  1.639104e+06                  4.90
# 3          1359955.0  2.569376e+07                  5.29
# 4           998319.0  1.789430e+07                  5.58
# ..               ...           ...                   ...
# 255        1720058.0  3.055526e+07                  5.63
# 256        1658461.0  2.374570e+07                  6.98
# 257         752812.0  1.288542e+07                  5.84
# 258        1489660.0  2.539947e+07                  5.86
# 259         107085.0  1.718579e+06                  6.23
#
#      Opioid_Prscrbng_Rate_5Y_Chg  Opioid_Prscrbng_Rate_1Y_Chg  \
# 0                          -1.32                        -0.27
# 1                          -1.40                        -0.42
# 2                          -2.01                        -0.90
# 3                          -1.79                        -0.33
# 4                          -1.08                        -0.32
# ..                           ...                          ...
# 255                          NaN                        -0.29
# 256                          NaN                        -0.19
# 257                          NaN                        -0.56
# 258                          NaN                        -0.15
# 259                          NaN                        -0.02
#
#      LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0             7290510.0                    11.02
# 1              138456.0                     7.63
# 2               13005.0                    16.19
# 3              184250.0                    13.55
# 4               76135.0                     7.63
# ..                  ...                      ...
# 255            201649.0                    11.72
# 256            281071.0                    16.95
# 257             69188.0                     9.19
# 258            263191.0                    17.67
# 259             17067.0                    15.94
#
#      LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                             -1.73                           -0.77
# 1                             -2.13                           -0.73
# 2                             -3.73                           -2.42
# 3                             -2.58                           -1.25
# 4                             -1.69                           -0.93
# ..                              ...                             ...
# 255                             NaN                            0.38
# 256                             NaN                           -0.20
# 257                             NaN                            0.25
# 258                             NaN                           -0.17
# 259                             NaN                            0.07
#
# [260 rows x 18 columns]

# %%
# Changing column name to state for merging late
care_clean = care_clean.rename(columns={"Prscrbr_Geo_Desc":"State"})
care_clean
# Out:
#      Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd          State  RUCA_Cd  \
# 0    2019        National             NaN       National      NaN
# 1    2019           State             1.0        Alabama      NaN
# 2    2019           State             2.0         Alaska      NaN
# 3    2019           State             4.0        Arizona      NaN
# 4    2019           State             5.0       Arkansas      NaN
# ..    ...             ...             ...            ...      ...
# 255  2015           State            51.0       Virginia      NaN
# 256  2015           State            53.0     Washington      NaN
# 257  2015           State            54.0  West Virginia      NaN
# 258  2015           State            55.0      Wisconsin      NaN
# 259  2015           State            56.0        Wyoming      NaN
#
#     Breakout_Type Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  \
# 0          Totals  Overall     1239380.0             803549.0
# 1          Totals  Overall       15575.0               9739.0
# 2          Totals  Overall        2847.0               1935.0
# 3          Totals  Overall       25876.0              16578.0
# 4          Totals  Overall        9700.0               7258.0
# ..            ...      ...           ...                  ...
# 255        Totals  Overall       25319.0              19755.0
# 256        Totals  Overall       25351.0              19532.0
# 257        Totals  Overall        7064.0               5174.0
# 258        Totals  Overall       20540.0              16177.0
# 259        Totals  Overall        1760.0               1363.0
#
#      Tot_Opioid_Clms      Tot_Clms  Opioid_Prscrbng_Rate  \
# 0         66138200.0  1.501140e+09                  4.41
# 1          1814583.0  2.800821e+07                  6.48
# 2            80311.0  1.639104e+06                  4.90
# 3          1359955.0  2.569376e+07                  5.29
# 4           998319.0  1.789430e+07                  5.58
# ..               ...           ...                   ...
# 255        1720058.0  3.055526e+07                  5.63
# 256        1658461.0  2.374570e+07                  6.98
# 257         752812.0  1.288542e+07                  5.84
# 258        1489660.0  2.539947e+07                  5.86
# 259         107085.0  1.718579e+06                  6.23
#
#      Opioid_Prscrbng_Rate_5Y_Chg  Opioid_Prscrbng_Rate_1Y_Chg  \
# 0                          -1.32                        -0.27
# 1                          -1.40                        -0.42
# 2                          -2.01                        -0.90
# 3                          -1.79                        -0.33
# 4                          -1.08                        -0.32
# ..                           ...                          ...
# 255                          NaN                        -0.29
# 256                          NaN                        -0.19
# 257                          NaN                        -0.56
# 258                          NaN                        -0.15
# 259                          NaN                        -0.02
#
#      LA_Tot_Opioid_Clms  LA_Opioid_Prscrbng_Rate  \
# 0             7290510.0                    11.02
# 1              138456.0                     7.63
# 2               13005.0                    16.19
# 3              184250.0                    13.55
# 4               76135.0                     7.63
# ..                  ...                      ...
# 255            201649.0                    11.72
# 256            281071.0                    16.95
# 257             69188.0                     9.19
# 258            263191.0                    17.67
# 259             17067.0                    15.94
#
#      LA_Opioid_Prscrbng_Rate_5Y_Chg  LA_Opioid_Prscrbng_Rate_1Y_Chg
# 0                             -1.73                           -0.77
# 1                             -2.13                           -0.73
# 2                             -3.73                           -2.42
# 3                             -2.58                           -1.25
# 4                             -1.69                           -0.93
# ..                              ...                             ...
# 255                             NaN                            0.38
# 256                             NaN                           -0.20
# 257                             NaN                            0.25
# 258                             NaN                           -0.17
# 259                             NaN                            0.07
#
# [260 rows x 18 columns]

# %%
#cdc_df

# %%
# Dropping years 2020 & 2021 and filtering indicator column 
cdc_year = cdc_df.loc[(cdc_df["Year"] != 2020) & (cdc_df["Year"] != 2021) & (cdc_df["State"] != 'YC')]
cdc_numofdeathsindicator = cdc_year.loc[(cdc_year["Indicator"]=="Number of Deaths")]

# Reset the index values for the dataframes
cdc_numofdeathsindicator = cdc_numofdeathsindicator.reset_index(drop=True)
cdc_numofdeathsindicator

# Changing column names for merging later
cdc_numofdeathsindicator = cdc_numofdeathsindicator.rename(columns={"State" : "State ID", "State Name" : "State"})
cdc_numofdeathsindicator['Data Value'] = pd.to_numeric(cdc_numofdeathsindicator['Data Value'], errors = 'coerce')
cdcnumofdeathsaggregated=cdc_numofdeathsindicator.groupby(['State ID', 'Year']).agg({'Data Value' : ['sum']})

cdcnumofdeathsaggregated
# Out:
#               Data Value
#                      sum
# State ID Year
# AK       2015    50086.0
#          2016    51141.0
#          2017    51597.0
#          2018    51865.0
#          2019    53484.0
# ...                  ...
# WY       2015    53812.0
#          2016    52723.0
#          2017    52181.0
#          2018    54073.0
#          2019    56144.0
#
# [260 rows x 1 columns]

# %%
# Dropping years 2020 & 2021 and filtering indicator column 
cdc_year = cdc_df.loc[(cdc_df["Year"] != 2020) & (cdc_df["Year"] != 2021) & (cdc_df["State"] != 'YC')]
cdc_numofdrugdeathsindicator = cdc_year.loc[(cdc_year["Indicator"]=="Number of Drug Overdose Deaths")]

# Reset the index values for the dataframes
cdc_numofdrugdeathsindicator = cdc_numofdrugdeathsindicator.reset_index(drop=True)
cdc_numofdrugdeathsindicator

# Changing column names for merging later
cdc_numofdrugdeathsindicator = cdc_numofdrugdeathsindicator.rename(columns={"State" : "State ID", "State Name" : "State"})
cdc_numofdrugdeathsindicator['Data Value'] = pd.to_numeric(cdc_numofdrugdeathsindicator['Data Value'], errors = 'coerce')
cdc_numofdrugdeathsaggregated=cdc_numofdrugdeathsindicator.groupby(['State ID', 'Year']).agg({'Data Value' : ['sum']})

cdc_numofdrugdeathsaggregated
# Out:
#               Data Value
#                      sum
# State ID Year
# AK       2015     1472.0
#          2016     1594.0
#          2017     1571.0
#          2018     1442.0
#          2019     1544.0
# ...                  ...
# WY       2015     1229.0
#          2016     1138.0
#          2017      871.0
#          2018      763.0
#          2019      797.0
#
# [260 rows x 1 columns]

# %%
# Dropping years 2020 & 2021 and filtering indicator column 
cdc_year = cdc_df.loc[(cdc_df["Year"] != 2020) & (cdc_df["Year"] != 2021) & (cdc_df["State"] != 'YC')]
cdc_numofopioiddeathsindicator = cdc_year.loc[(cdc_year["Indicator"]=="Opioids (T40.0-T40.4,T40.6)")]

# Reset the index values for the dataframes
cdc_numofopioiddeathsindicator = cdc_numofopioiddeathsindicator.reset_index(drop=True)
cdc_numofopioiddeathsindicator
                                                                             
                                                                             
# Changing column names for merging later
cdc_numofopioiddeathsindicator = cdc_numofopioiddeathsindicator.rename(columns={"State" : "State ID", "State Name" : "State"})
cdc_numofopioiddeathsindicator['Data Value'] = pd.to_numeric(cdc_numofopioiddeathsindicator['Data Value'], errors = 'coerce')
cdc_numofopioiddeathsaggregated=cdc_numofopioiddeathsindicator.groupby(['State ID', 'Year']).agg({'Data Value' : ['sum']})

cdc_numofopioiddeathsaggregated
# Out:
#               Data Value
#                      sum
# State ID Year
# AK       2015      165.0
#          2016     1163.0
#          2017     1110.0
#          2018      990.0
#          2019      962.0
# ...                  ...
# WY       2015        0.0
#          2016        0.0
#          2017      404.0
#          2018      497.0
#          2019      508.0
#
# [225 rows x 1 columns]

# %%
# Merging Medicaid & Medicare data with an Outer Join
insurance = pd.merge(care_clean, caid_clean, how = "outer", on = ["Year", "State"])
insurance
# Out:
#      Year Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd          State  RUCA_Cd  \
# 0    2019        National             NaN       National      NaN
# 1    2019           State             1.0        Alabama      NaN
# 2    2019           State             2.0         Alaska      NaN
# 3    2019           State             4.0        Arizona      NaN
# 4    2019           State             5.0       Arkansas      NaN
# ..    ...             ...             ...            ...      ...
# 255  2015           State            51.0       Virginia      NaN
# 256  2015           State            53.0     Washington      NaN
# 257  2015           State            54.0  West Virginia      NaN
# 258  2015           State            55.0      Wisconsin      NaN
# 259  2015           State            56.0        Wyoming      NaN
#
#     Breakout_Type Breakout  Tot_Prscrbrs  Tot_Opioid_Prscrbrs  \
# 0          Totals  Overall     1239380.0             803549.0
# 1          Totals  Overall       15575.0               9739.0
# 2          Totals  Overall        2847.0               1935.0
# 3          Totals  Overall       25876.0              16578.0
# 4          Totals  Overall        9700.0               7258.0
# ..            ...      ...           ...                  ...
# 255        Totals  Overall       25319.0              19755.0
# 256        Totals  Overall       25351.0              19532.0
# 257        Totals  Overall        7064.0               5174.0
# 258        Totals  Overall       20540.0              16177.0
# 259        Totals  Overall        1760.0               1363.0
#
#      Tot_Opioid_Clms_x  ...  Plan_Type  Tot_Opioid_Clms_y   Tot_Clms_y  \
# 0           66138200.0  ...        All         21978286.0  677248025.0
# 1            1814583.0  ...        All           224310.0    7230251.0
# 2              80311.0  ...        All            65394.0    1434139.0
# 3            1359955.0  ...        All           595206.0   14923326.0
# 4             998319.0  ...        All           216081.0    4999626.0
# ..                 ...  ...        ...                ...          ...
# 255          1720058.0  ...        All           583116.0   10186332.0
# 256          1658461.0  ...        All          1136474.0   14016747.0
# 257           752812.0  ...        All           520370.0    9293729.0
# 258          1489660.0  ...        All           962286.0   11306189.0
# 259           107085.0  ...        All            39088.0     534212.0
#
#      Opioid_Prscrbng_Rate_y  Opioid_Prscrbng_Rate_5Y_Chg_y  \
# 0                      3.25                          -3.22
# 1                      3.10                          -3.23
# 2                      4.56                          -3.33
# 3                      3.99                          -5.14
# 4                      4.32                          -3.12
# ..                      ...                            ...
# 255                    5.72                            NaN
# 256                    8.11                            NaN
# 257                    5.60                            NaN
# 258                    8.51                            NaN
# 259                    7.32                            NaN
#
#      Opioid_Prscrbng_Rate_1Y_Chg_y  LA_Tot_Opioid_Clms_y  \
# 0                            -0.44             3108845.0
# 1                            -1.08               10308.0
# 2                            -1.20                8268.0
# 3                            -0.75               44311.0
# 4                            -0.88                8129.0
# ..                             ...                   ...
# 255                          -0.62               42311.0
# 256                          -0.89              106143.0
# 257                          -1.30               25575.0
# 258                          -0.35              146248.0
# 259                          -0.48                3792.0
#
#      LA_Opioid_Prscrbng_Rate_y LA_Opioid_Prscrbng_Rate_5Y_Chg_y  \
# 0                        14.15                             6.67
# 1                         4.60                             0.16
# 2                        12.64                             0.88
# 3                         7.44                            -2.79
# 4                         3.76                            -0.34
# ..                         ...                              ...
# 255                       7.26                              NaN
# 256                       9.34                              NaN
# 257                       4.91                              NaN
# 258                      15.20                              NaN
# 259                       9.70                              NaN
#
#      LA_Opioid_Prscrbng_Rate_1Y_Chg_y
# 0                                4.62
# 1                                0.48
# 2                               -0.71
# 3                               -0.52
# 4                               -1.05
# ..                                ...
# 255                             -0.26
# 256                              0.18
# 257                              0.66
# 258                              1.04
# 259                             -0.49
#
# [260 rows x 30 columns]

# %%
# Merging CDC data & Insurace Data w/ an outer join and on Year and State
#data = pd.merge(cdcnumofdeathsaggregated, insurance, how = "outer", on = ["Year", "State"])
#data

# %%
## Creating Google Heatmaps of Overdose Deaths by State
# Import Google API key for configuration
gmaps.configure(api_key = g_key)

# Importing mean population center coordinates for the 50 states so that data points coincide with centers
state_lat_long_df = pd.read_csv("Resource/CenPop2020_Mean_ST.csv")
state_lat_long_df = state_lat_long_df.loc[state_lat_long_df['STNAME'] != 'Puerto Rico']
state_coords = state_lat_long_df[['LATITUDE', 'LONGITUDE']]

# Filtering out cdc_numofdrugdeathsaggregated to exclude the total US deaths
# The year had to be manually changed to get heatmaps of overdose deaths 
# for the analysed years (2015, 2016, 2017, 2018, & 2019)
num_deaths_df = cdc_numofdrugdeathsaggregated.reset_index().droplevel(level = 1, axis = 1).rename(columns = {'Data Value':'Sum'})
num_deaths_year_df = num_deaths_df.loc[(num_deaths_df['Year'] == 2019) & (num_deaths_df['State ID'] != 'US')]
num_deaths_year = num_deaths_year_df['Sum']

# Layout of the map
layout = {'width': '1000px', 'height': '500px', 'border': '1px solid black', 'paddling': '1px'}
# Centered the figure on the mean population center of the United States including Alaska and Hawaii
# https://www.census.gov/geographies/reference-files/time-series/geo/centers-population.html
center = [44.97, -103.77]

# Generating the heatmap
fig = gmaps.figure(map_type = 'HYBRID', layout = layout, center = center, zoom_level = 3)
heat = gmaps.heatmap_layer(state_coords, weights = num_deaths_year, dissipating = False, \
                           max_intensity = 5e4, point_radius = 3)

fig.add_layer(heat)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', width='1000px'))

# %%
state_lat_long_df
# Out:
#     STATEFP                STNAME  POPULATION   LATITUDE   LONGITUDE
# 0         1               Alabama     5024279  33.016191  -86.753353
# 1         2                Alaska      733391  61.408891 -148.961508
# 2         4               Arizona     7151502  33.371388 -111.882468
# 3         5              Arkansas     3011524  35.199251  -92.713212
# 4         6            California    39538223  35.491035 -119.347852
# 5         8              Colorado     5773714  39.534747 -105.185361
# 6         9           Connecticut     3605944  41.492835  -72.878714
# 7        10              Delaware      989948  39.333614  -75.547709
# 8        11  District of Columbia      689545  38.910168  -77.013993
# 9        12               Florida    21538187  27.839295  -81.636016
# 10       13               Georgia    10711908  33.410677  -83.891248
# 11       15                Hawaii     1455271  21.112376 -157.485304
# 12       16                 Idaho     1839106  44.220476 -115.224610
# 13       17              Illinois    12812508  41.312077  -88.372974
# 14       18               Indiana     6785528  40.144178  -86.251589
# 15       19                  Iowa     3190369  41.936630  -93.037218
# 16       20                Kansas     2937880  38.480984  -96.409286
# 17       21              Kentucky     4505836  37.838308  -85.261296
# 18       22             Louisiana     4657757  30.696198  -91.474266
# 19       23                 Maine     1362359  44.267404  -69.764596
# 20       24              Maryland     6177224  39.136636  -76.802227
# 21       25         Massachusetts     7029917  42.273659  -71.350366
# 22       26              Michigan    10077331  42.864675  -84.213172
# 23       27             Minnesota     5706494  45.189990  -93.558751
# 24       28           Mississippi     2961279  32.575361  -89.566275
# 25       29              Missouri     6154913  38.432921  -92.234929
# 26       30               Montana     1084225  46.760509 -111.318567
# 27       31              Nebraska     1961504  41.167883  -97.222143
# 28       32                Nevada     3104614  37.015907 -116.173753
# 29       33         New Hampshire     1377529  43.149147  -71.455608
# 30       34            New Jersey     9288994  40.438248  -74.424465
# 31       35            New Mexico     2117522  34.607808 -106.332167
# 32       36              New York    20201249  41.471783  -74.590827
# 33       37        North Carolina    10439388  35.538715  -79.675021
# 34       38          North Dakota      779094  47.339540  -99.444952
# 35       39                  Ohio    11799448  40.438553  -82.796902
# 36       40              Oklahoma     3959353  35.606866  -96.854171
# 37       41                Oregon     4237256  44.753509 -122.588257
# 38       42          Pennsylvania    13002700  40.443486  -76.965232
# 39       44          Rhode Island     1097379  41.755677  -71.450484
# 40       45        South Carolina     5118425  34.022471  -80.996482
# 41       46          South Dakota      886667  43.986511  -98.922285
# 42       47             Tennessee     6910840  35.821189  -86.332487
# 43       48                 Texas    29145505  30.909581  -97.328656
# 44       49                  Utah     3271616  40.385835 -111.948021
# 45       50               Vermont      643077  44.101952  -72.824240
# 46       51              Virginia     8631393  37.850195  -77.765608
# 47       53            Washington     7705281  47.329504 -121.632620
# 48       54         West Virginia     1793716  38.823276  -80.671314
# 49       55             Wisconsin     5893718  43.723662  -89.031445
# 50       56               Wyoming      576851  42.694801 -106.984779
# 51       72           Puerto Rico     3285874  18.282916  -66.348925

# %%
len(state_coords)
# Out:
# 52
